# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#import data
Data=pd.read_csv("Durham-Transfomed-Data.csv")

# %%
# Make correlation matrix
corr_matrix = Data.corr(method = "spearman").abs()
corr_matrix
# Out:
#                   FailureMonth  LiningAge  LiningMaterial  InstallMonth  \
# FailureMonth          1.000000   0.092924        0.080138      0.009332
# LiningAge             0.092924   1.000000        0.953325      0.164013
# LiningMaterial        0.080138   0.953325        1.000000      0.172154
# InstallMonth          0.009332   0.164013        0.172154      1.000000
# ProtectionStatus      0.019992   0.233589        0.259514      0.071714
# Status                0.021134   0.108009        0.114294      0.223808
# Material              0.135944   0.426376        0.404749      0.040088
# LiningStatus          0.080028   0.955549        0.999758      0.172245
# AgeAtProtection       0.009246   0.207998        0.240808      0.065479
# Length                0.044833   0.052185        0.051137      0.022722
# Age                   0.083831   0.058615        0.042061      0.192971
# Diameter              0.024837   0.035813        0.009173      0.127852
# PreviousRoF           0.127684   0.000349        0.006841      0.080211
# CurrentRoF            0.028718   0.049491        0.047231      0.014556
#
#                   ProtectionStatus    Status  Material  LiningStatus  \
# FailureMonth              0.019992  0.021134  0.135944      0.080028
# LiningAge                 0.233589  0.108009  0.426376      0.955549
# LiningMaterial            0.259514  0.114294  0.404749      0.999758
# InstallMonth              0.071714  0.223808  0.040088      0.172245
# ProtectionStatus          1.000000  0.086548  0.381402      0.260757
# Status                    0.086548  1.000000  0.041763      0.114223
# Material                  0.381402  0.041763  1.000000      0.404681
# LiningStatus              0.260757  0.114223  0.404681      1.000000
# AgeAtProtection           0.972736  0.097298  0.327682      0.241990
# Length                    0.102011  0.033646  0.003509      0.050802
# Age                       0.048497  0.112910  0.020224      0.042464
# Diameter                  0.076269  0.088042  0.003402      0.009909
# PreviousRoF               0.095482  0.106822  0.172689      0.005369
# CurrentRoF                0.103348  0.037219  0.008767      0.047175
#
#                   AgeAtProtection    Length       Age  Diameter  PreviousRoF  \
# FailureMonth             0.009246  0.044833  0.083831  0.024837     0.127684
# LiningAge                0.207998  0.052185  0.058615  0.035813     0.000349
# LiningMaterial           0.240808  0.051137  0.042061  0.009173     0.006841
# InstallMonth             0.065479  0.022722  0.192971  0.127852     0.080211
# ProtectionStatus         0.972736  0.102011  0.048497  0.076269     0.095482
# Status                   0.097298  0.033646  0.112910  0.088042     0.106822
# Material                 0.327682  0.003509  0.020224  0.003402     0.172689
# LiningStatus             0.241990  0.050802  0.042464  0.009909     0.005369
# AgeAtProtection          1.000000  0.089444  0.002952  0.106381     0.086297
# Length                   0.089444  1.000000  0.025020  0.138887     0.107677
# Age                      0.002952  0.025020  1.000000  0.213021     0.261689
# Diameter                 0.106381  0.138887  0.213021  1.000000     0.140058
# PreviousRoF              0.086297  0.107677  0.261689  0.140058     1.000000
# CurrentRoF               0.093602  0.966811  0.017005  0.127873     0.085486
#
#                   CurrentRoF
# FailureMonth        0.028718
# LiningAge           0.049491
# LiningMaterial      0.047231
# InstallMonth        0.014556
# ProtectionStatus    0.103348
# Status              0.037219
# Material            0.008767
# LiningStatus        0.047175
# AgeAtProtection     0.093602
# Length              0.966811
# Age                 0.017005
# Diameter            0.127873
# PreviousRoF         0.085486
# CurrentRoF          1.000000

# %%
corr_matrix.to_csv("C:/Users/sgharaa/Desktop/Correlation/RoF/Winnipeg.csv")
