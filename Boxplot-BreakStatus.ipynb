# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"
from matplotlib import pyplot

# %%
Data=pd.read_csv("Correlation-BreakStatus.csv")

# %%
#Data2=Data.iloc[:,:8]

# %%
Data
# Out:
#    Unnamed: 0   Unnamed: 1  Diameter    Length  Joint type  Restrained  \
# 0      Barrie  BreakStatus  0.268124  0.331802         NaN    0.051749
# 1     Calgary  BreakStatus  0.247838  0.435778         NaN         NaN
# 2      Durham  BreakStatus  0.187557  0.349657         NaN         NaN
# 3     Halifax  BreakStatus  0.294088  0.530173         NaN         NaN
# 4   Kitchener  BreakStatus  0.204043  0.422900         NaN         NaN
# 5     Markham  BreakStatus  0.158392  0.459616         NaN         NaN
# 6         RoW  BreakStatus  0.000517  0.105397         NaN         NaN
# 7   Saskatoon  BreakStatus  0.178977  0.416865    0.332531         NaN
# 8     StJohns  BreakStatus  0.204951  0.309529         NaN         NaN
# 9   Vancouver  BreakStatus  0.065831  0.057457         NaN         NaN
# 10   Victoria  BreakStatus  0.143183  0.373433         NaN         NaN
# 11   Waterloo  BreakStatus  0.074941  0.325472         NaN         NaN
# 12   Winnipeg  BreakStatus  0.124812       NaN         NaN         NaN
#
#     Material       Age  Failure month  Install month  ...  Protection age  \
# 0   0.526932  0.181134       0.177865            NaN  ...             NaN
# 1   0.515914  0.066256            NaN            NaN  ...             NaN
# 2   0.585872  0.190701       0.283193            NaN  ...        0.343447
# 3   0.653016  0.204696       0.373180            NaN  ...             NaN
# 4   0.271254  0.214487       0.285286            NaN  ...             NaN
# 5   0.689496  0.009310       0.146492            NaN  ...        0.679715
# 6   0.051220  0.331014       0.119595            NaN  ...             NaN
# 7   0.419459  0.027524            NaN            NaN  ...             NaN
# 8   0.336346  0.129368       0.197352            NaN  ...             NaN
# 9   0.079959  0.076080       0.176535            NaN  ...             NaN
# 10  0.268457  0.016944       0.214914            NaN  ...             NaN
# 11  0.353654  0.209399       0.220675       0.107944  ...             NaN
# 12  0.582236  0.257246       0.104932            NaN  ...             NaN
#
#     Lining status  Lining material  Lining age  Coating material  \
# 0             NaN              NaN         NaN               NaN
# 1             NaN              NaN         NaN               NaN
# 2        0.057597         0.057697    0.030061               NaN
# 3        0.287898         0.287701         NaN               NaN
# 4        0.017556         0.017578    0.014444               NaN
# 5        0.415602              NaN    0.381450               NaN
# 6        0.061466         0.061466    0.111565               NaN
# 7        0.014952         0.014955    0.026805               NaN
# 8             NaN              NaN         NaN               NaN
# 9             NaN         0.053688         NaN          0.035952
# 10       0.005710         0.081133         NaN               NaN
# 11       0.065706         0.067029    0.040901               NaN
# 12            NaN              NaN         NaN          0.001502
#
#     Casing material  Service type       HGL  Roughness  Dead end
# 0          0.054678      0.078570       NaN        NaN       NaN
# 1               NaN           NaN       NaN        NaN  0.120536
# 2               NaN           NaN       NaN        NaN       NaN
# 3               NaN           NaN       NaN        NaN       NaN
# 4               NaN           NaN       NaN        NaN       NaN
# 5               NaN           NaN       NaN        NaN       NaN
# 6               NaN           NaN       NaN        NaN       NaN
# 7               NaN           NaN       NaN        NaN       NaN
# 8               NaN           NaN       NaN   0.336769       NaN
# 9               NaN      0.003966       NaN        NaN       NaN
# 10              NaN           NaN  0.031235        NaN       NaN
# 11              NaN      0.006222       NaN        NaN       NaN
# 12              NaN           NaN       NaN        NaN       NaN
#
# [13 rows x 23 columns]

# %%
boxprops=dict(linestyle='-', linewidth=4,  color='Blue')
medianprops = dict(linestyle='-', linewidth=4, color='green')
whiskerprops=dict(linestyle='-', linewidth=4, color='Blue')
capprops=dict(linestyle='-', linewidth=4, color='black')
flierprops = dict(marker='o', markersize=18,
                  linestyle='none', markeredgecolor="black")

# %%
figure=Data.boxplot(rot=45,figsize=(70,45),fontsize=70,boxprops=boxprops, medianprops=medianprops,whiskerprops=whiskerprops, capprops=capprops,  grid=True,flierprops=flierprops)
                    #flierprops=flierprops
figure.set_ylabel("correlation coefficient",fontsize=70)
figure.set_ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
figure.figure.savefig('Boxplot-BreakStatus.png')

# %%
capprops=dict(linestyle='-', linewidth=4, color='black')
medianprops = dict(linestyle='-', linewidth=4, color='black')
whiskerprops=dict(linestyle='-', linewidth=4, color='black')
flierprops = dict(marker='o', markersize=18,
                  linestyle='none', markeredgecolor="black")
plt.figure(figsize=(75,45))
chart = sns.boxplot(
    data=Data,  medianprops=medianprops, capprops=capprops, whiskerprops=whiskerprops,flierprops=flierprops, color="Blue"
)

sns.set(font_scale=5)
sns.set_style("whitegrid")
#chart.set_ylabel("Correlation coefficient",fontsize=60)
#chart.set_xlabel("Break status attributes", fontsize=60)
plt.ylim(0, 1) 
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, fontsize=70)
#chart.set_yticklabels(chart.get_ymajorticklabels(), fontsize = 18)
chart.xaxis.grid(True)
chart.yaxis.grid(True)
#chart.axes.set_title("correlation coefficent - break status",fontsize=100, y=1)

# %%
chart.figure.savefig('Boxplot-BreakStatus-colourfull.png')
