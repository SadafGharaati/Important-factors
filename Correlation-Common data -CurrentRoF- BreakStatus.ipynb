# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#import data
Data=pd.read_csv("Common_attributes_all.csv")

# %%
# Make correlation matrix
corr_matrix = Data.corr(method = "spearman").abs()

# Draw the heatmap
sns.set(font_scale = 2.0)
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr_matrix, cmap= "YlGnBu", square=True, ax = ax)
f.tight_layout()
plt.savefig("correlation_matrix_RoF.png", dpi = 1080)

# %%
#import data
Data2=pd.read_csv("Common-attributes-BreakStatus.csv")

# %%
# Make correlation matrix
corr_matrix = Data2.corr(method = "spearman").abs()

# Draw the heatmap
sns.set(font_scale = 2.0)
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr_matrix, cmap= "YlGnBu", square=True, ax = ax)
f.tight_layout()
plt.savefig("correlation_matrix_BreakStatus.png", dpi = 1080)
